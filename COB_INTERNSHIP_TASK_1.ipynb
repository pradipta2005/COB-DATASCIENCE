# %%
import pandas as pd
import requests

# %%
api_data=requests.get(r"https://data.binance.com/api/v3/ticker/24hr")

# %%
data=api_data.json()

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#     symbol priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  0.00050000              0.816       0.06154284     0.06128000
# 1   LTCBTC  0.00010300              4.344       0.00245326     0.00237200
# 2   BNBBTC  0.00013000              1.629       0.00805143     0.00798200
# 3   NEOBTC  0.00000300              1.095       0.00027690     0.00027390
# 4  QTUMETH  0.00001900              1.432       0.00135120     0.00132200
#
#     lastPrice     lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.06177000  0.46130000  0.06177000   21.70000000  0.06178000  ...
# 1  0.00247400  0.34300000  0.00247400  111.34400000  0.00247500  ...
# 2  0.00811200  0.81500000  0.00811100   26.29500000  0.00811200  ...
# 3  0.00027690  2.80000000  0.00027690   16.80000000  0.00027710  ...
# 4  0.00134600  4.90000000  0.00135100   45.20000000  0.00135600  ...
#
#     openPrice   highPrice    lowPrice          volume   quoteVolume  \
# ...

# %%
df.to_csv(r"C:\Users\ADMIN\OneDrive\Documents\Desktop\\COB_INTERNSHIP_TASK_1.csv",index=False)
