# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ADMIN\OneDrive\Documents\Desktop\dataset - netflix1.csv")

# %%
df.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df['director']=df['director'].replace('Not Given',np.NaN)
df['country']=df['country'].replace('Not Given',np.NaN)

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre              NaN
# 8786   s8798  TV Show                         Zak Storm              NaN
# 8787   s8801  TV Show                Zindagi Gulzar Hai              NaN
# 8788   s8784  TV Show                              Yoko              NaN
# 8789   s8786  TV Show                               YOM              NaN
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2588
# country          287
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# dtype: int64

# %%
df2=df.dropna(axis=0,how='any')

# %%
df2.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
print("After removing missing values",len(df2),"rows are present in the list.")
# Out:
# After removing missing values 5915 rows are present in the list.

# %%
df2
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 4         s8    Movie                            Sankofa
# ...      ...      ...                                ...
# 6565   s3351    Movie         True: Grabbleapple Harvest
# 6566   s3509    Movie             True: Tricky Treat Day
# 6567   s3554  TV Show       True and the Rainbow Kingdom
# 6568   s4241    Movie  Sam Kinison: The Scream Continues
# 6569   s1315  TV Show                   Chappelle's Show
#
#                           director        country  date_added  release_year  \
# 0                  Kirsten Johnson  United States   9/25/2021          2020
# 1                  Julien Leclercq         France   9/24/2021          2021
# ...

# %%
df2.to_csv(r"C:\Users\ADMIN\OneDrive\Documents\Desktop\\Clean_Missing_Value.csv",index=False)

# %%
import seaborn as sns

# %%
sns.boxplot(x=df2['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x=df2['release_year'],kde=True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %%
df2.describe()
# Out:
#        release_year
# count   5915.000000
# mean    2013.014708
# std        9.693770
# min     1942.000000
# 25%     2012.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
upper_limit=2018+1.5*6
lower_limit=2012-1.5*6

# %%
upper_limit
# Out:
# 2027.0

# %%
lower_limit
# Out:
# 2003.0

# %%
new_data=df2.loc[(df2['release_year']<upper_limit) & (df2['release_year']>lower_limit)]

# %%
new_data['release_year'].median()
# Out:
# 2017.0

# %%
sns.boxplot(x=new_data['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x=new_data['release_year'],kde=True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %%
lower_limit=2016-1.5*6
lower_limit
# Out:
# 2007.0

# %%
new_data_1=new_data.loc[(new_data['release_year']<upper_limit) & (new_data['release_year']>lower_limit)]

# %%
sns.boxplot(x=new_data_1['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x=new_data_1['release_year'],kde=True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %%
lower_limit=2018-1.5*6
lower_limit
# Out:
# 2009.0

# %%
new_data_2=new_data_1.loc[(new_data_1['release_year']<upper_limit) & (new_data_1['release_year']>lower_limit)]

# %%
sns.boxplot(x=new_data_2['release_year'])
# Out:
# <Axes: xlabel='release_year'>

# %%
sns.histplot(x=new_data_2['release_year'],kde=True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %%
print("After removing outliers", len(new_data_2), "rows are present in the Dataset")
# Out:
# After removing outliers 4777 rows are present in the Dataset

# %%
new_data_2
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 5         s9  TV Show      The Great British Baking Show
# ...      ...      ...                                ...
# 6564   s2543  TV Show               True: Terrific Tales
# 6565   s3351    Movie         True: Grabbleapple Harvest
# 6566   s3509    Movie             True: Tricky Treat Day
# 6567   s3554  TV Show       True and the Rainbow Kingdom
# 6568   s4241    Movie  Sam Kinison: The Scream Continues
#
#                           director         country  date_added  release_year  \
# 0                  Kirsten Johnson   United States   9/25/2021          2020
# 1                  Julien Leclercq          France   9/24/2021          2021
# ...

# %%
new_data_2.to_csv(r"C:\Users\ADMIN\OneDrive\Documents\\COB_INTERNSHIP_TASK_2.csv",index=False)

# %%
import matplotlib.pyplot as plt

# %%
new_data_2.type.value_counts()
# Out:
# type
# Movie      4569
# TV Show     208
# Name: count, dtype: int64

# %%
new_data_2['country'].value_counts().head()
# Out:
# country
# United States     1830
# India              726
# United Kingdom     339
# Canada             179
# France             143
# Name: count, dtype: int64

# %%
sns.countplot(x='type',data=df)
plt.title('Count vs Type of shows')
# Out:
# Text(0.5, 1.0, 'Count vs Type of shows')

# %% [markdown]
# This Graph is Plloted on Given Dataset Which is not clean.(Not removed Missing Values and Outliers)

# %%
plt.figure(figsize=(14,6))
sns.countplot(y=new_data_2['country'],order=new_data_2['country'].value_counts().index[0:10])
plt.title('Country Wise Content On Netflix')
# Out:
# Text(0.5, 1.0, 'Country Wise Content On Netflix')

# %%
movie_countries=new_data_2[new_data_2['type']=='Movie']
tv_show_countries=new_data_2[new_data_2['type']=='TV Show']

# %%
tv_show_countries
# Out:
#      show_id     type                          title  \
# 1         s3  TV Show                      Ganglands
# 2         s6  TV Show                  Midnight Mass
# 5         s9  TV Show  The Great British Baking Show
# 20     s4832  TV Show          True: Magical Friends
# 21     s4833  TV Show         True: Wonderful Wishes
# ...      ...      ...                            ...
# 6559   s8412  TV Show    The Making of Frozen Planet
# 6560     s40  TV Show                   Chhota Bheem
# 6562   s8438  TV Show         The Netflix Afterparty
# 6564   s2543  TV Show           True: Terrific Tales
# 6567   s3554  TV Show   True and the Rainbow Kingdom
#
#                              director         country date_added  \
# 1                     Julien Leclercq          France  9/24/2021
# 2                       Mike Flanagan   United States  9/24/2021
# 5                     Andy Devonshire  United Kingdom  9/24/2021
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='country',order=new_data_2['country'].value_counts().index[0:10],data=movie_countries)
plt.title('Top 10 Countries producing Movies in Netflix')






plt.figure(figsize=(12,6))
sns.countplot(y='country',order=new_data_2['country'].value_counts().index[0:10],data=tv_show_countries)
plt.title('Top 10 Countries producing Tv shows in Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries producing Tv shows in Netflix')

# %%
ds=new_data_2.copy()

# %%
ds
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 5         s9  TV Show      The Great British Baking Show
# ...      ...      ...                                ...
# 6564   s2543  TV Show               True: Terrific Tales
# 6565   s3351    Movie         True: Grabbleapple Harvest
# 6566   s3509    Movie             True: Tricky Treat Day
# 6567   s3554  TV Show       True and the Rainbow Kingdom
# 6568   s4241    Movie  Sam Kinison: The Scream Continues
#
#                           director         country  date_added  release_year  \
# 0                  Kirsten Johnson   United States   9/25/2021          2020
# 1                  Julien Leclercq          France   9/24/2021          2021
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(y='director',order=ds['director'].value_counts().index[0:20],data=ds)
plt.title("Top 20  Director's Shows On Netflix")
# Out:
# Text(0.5, 1.0, "Top 20  Director's Shows On Netflix")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='rating',order=ds['rating'].value_counts().index[0:10],data=ds)
plt.title('Ratings Of Shows On Netflix Vs Count')
# Out:
# Text(0.5, 1.0, 'Ratings Of Shows On Netflix Vs Count')

# %%
ds.release_year.value_counts()
# Out:
# release_year
# 2017    744
# 2018    730
# 2016    645
# 2019    598
# 2020    503
# 2015    386
# 2014    262
# 2013    223
# 2021    219
# 2012    175
# 2010    148
# 2011    144
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='release_year',order=ds['release_year'].value_counts().index[0:30],data=ds)
plt.title('Content Release in Years on Netflix Vs Count')
# Out:
# Text(0.5, 1.0, 'Content Release in Years on Netflix Vs Count')

# %%
plt.figure(figsize=(12,8))
sns.countplot(y='listed_in',order=ds['listed_in'].value_counts().index[0:20],data=ds)
plt.title('Top 20 Genres on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 20 Genres on Netflix')

# %% [raw]
# SUMMARY:
# So far I had perform lots of operations over the dataset to dig out some very useful information from it.If I have to conclude the dataset in few line,than we can say that:
#
#      * Netflix has more Movies than TV Shows
#      * Most number of Movies and TV Shows are produced by United States,followed by India who has produced the second most number of movies on
#       Netflix.
#      * 2017 is the year in which Netflix released alot more content as compared to other years.
#      *  Documentaries are the most popular Genres on Netflix.
