# %%
import pandas as pd
import requests

# %%
api_data=requests.get(r"https://data.binance.com/api/v3/ticker/24hr")

# %%
data=api_data.json()

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  -0.00040000             -0.636       0.06265516     0.06292000
# 1   LTCBTC  -0.00001300             -0.543       0.00236949     0.00239200
# 2   BNBBTC  -0.00004900             -0.595       0.00823076     0.00824200
# 3   NEOBTC  -0.00000200             -0.720       0.00027534     0.00027770
# 4  QTUMETH   0.00000000              0.000       0.00127789     0.00128600
#
#     lastPrice      lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.06252000   3.11000000  0.06252000   12.37620000  0.06253000  ...
# 1  0.00238000  24.82500000  0.00237900  147.93900000  0.00238000  ...
# 2  0.00819300   0.12200000  0.00819200    4.10300000  0.00819300  ...
# 3  0.00027560   1.67000000  0.00027550    4.46000000  0.00027560  ...
# 4  0.00128400   1.10000000  0.00128500   48.10000000  0.00128800  ...
#
#     openPrice   highPrice    lowPrice          volume   quoteVolume  \
# 0  0.06292000  0.06305000  0.06235000  14220.93820000  891.01518540
# 1  0.00239300  0.00239500  0.00234100  51332.98300000  121.63296203
# 2  0.00824200  0.00826800  0.00819100  18763.35900000  154.43663246
# 3  0.00027760  0.00027870  0.00027180  11895.56000000    3.27533162
# 4  0.00128400  0.00128900  0.00127300    841.30000000    1.07509300
#
#         openTime      closeTime    firstId     lastId  count
# 0  1694329118151  1694415518151  422855356  422879930  24575
# 1  1694329124479  1694415524479   93428627   93436578   7952
# 2  1694329117822  1694415517822  226927450  226948356  20907
# 3  1694329104629  1694415504629   45490398   45496575   6178
# 4  1694329084098  1694415484098    5401518    5401563     46
#
# [5 rows x 21 columns]

# %%
df.to_csv(r"C:\Users\ADMIN\OneDrive\Documents\\TASK1")
